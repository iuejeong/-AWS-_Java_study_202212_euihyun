# %%
import numpy as np
import math

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

def split_len(data_list):
    len_list=[]
    for e in data_list:
        len_list.append(len(e))
    print(set(len_list))
    if len(set(len_list))>1:
        for i in set(len_list):
            print(i, len_list.count(i))
    return set(len_list)

def dist_np(p1, p2): #  [3,10]  [5,25]
    return math.sqrt(sum((p2-p1)**2))

# %%
csv_data = []
with open('전국공인중개사사무소표준데이터.csv') as f:
    for line in f:
        csv_data.append(my_split(line[:-1]))
        
np_data = np.array(csv_data)
for e in enumerate(np_data[0]):
    print(e)
# Out:
# (0, '중개사무소명')
# (1, '개설등록번호')
# (2, '개업공인중개사종별구분')
# (3, '소재지도로명주소')
# (4, '소재지지번주소')
# (5, '전화번호')
# (6, '개설등록일자')
# (7, '공제가입유무')
# (8, '대표자명')
# (9, '위도')
# (10, '경도')
# (11, '중개보조원수')
# (12, '소속공인중개사수')
# (13, '홈페이지주소')
# (14, '데이터기준일자')
# (15, '제공기관코드')
# (16, '제공기관명')

# %%
print(np_data[:3])
# Out:
# [['중개사무소명' '개설등록번호' '개업공인중개사종별구분' '소재지도로명주소' '소재지지번주소' '전화번호' '개설등록일자'
#   '공제가입유무' '대표자명' '위도' '경도' '중개보조원수' '소속공인중개사수' '홈페이지주소' '데이터기준일자'
#   '제공기관코드' '제공기관명']
#  ['제일공인중개사사무소' '26710-2015-00005' '공인중개사' '부산광역시 기장군 정관읍 구연로 26' '' ''
#   '2015-01-07' 'Y' '송미경' '' '' '' '' '' '2022-11-25' '3400000'
#   '부산광역시 기장군']
#  ['늘채움부동산공인중개사사무소' '26710-2015-00013' '공인중개사'
#   '"부산광역시 기장군 기장읍 차성남로 91, 1층 일부"' '' '' '2015-01-21' 'Y' '강경미' '' '' ''
#   '' '' '2022-11-25' '3400000' '부산광역시 기장군']]

# %%
btypes = np_data[1:, 2]
# print(btypes)
btype_name, btype_count = np.unique(btypes, return_counts = True)
print(btype_name)
print(btype_count)
print(btype_count * 100 / sum(btype_count))
# Out:
# ['개업공인중개사' '공인중개사' '법인']
# [ 5085 23757   527]
# [17.31417481 80.89141612  1.79440907]

# %%
y_n = np_data[1:, 7]
np.unique(y_n, return_counts=True)
# Out:
# (array(['N', 'Y'], dtype='<U74'), array([   30, 29339], dtype=int64))

# %%
names = np_data[1:, 0]
name_head = []
else_list = []
for n in names:
    if '공인중개사' in n:
        name_head.append(n[:n.index('공인중개사')])
    else:
        else_list.append(n)
print(name_head)
# Out:
# ['제일', '늘채움부동산', '해부동산', '동부산오시리아명성부동산', 'OK부동산', '신태양', '롯데황금', '삼보', '알뜰부동산', '드림', '스마일', '재테크', '김종국', '대원', '한국부동산', '대일', '머니부동산', '최고집', '썬', '양지', '삼성', '혜현윤', '전국', '희망', '한국', '큰부자부동산', '이루다', '차오름', '이룸', '광주역자이', '행복 ', '착한', '동일', '초월역힐스', '인스페이스공간', '삼거리', '리치', '햇빛부동산', 'JK홈즈', '뉴케이지', '광주', '약속의땅', '세창', '미르', '한라비발디', '베타', '한아람', '한솔부동산', '비오비', 'sk', '리치메이커', '초월역황금', '곤지암아이파크', '골드부동산', '한아름', '성문', '원탑', '한아름', '', '뉴한길', '태전명품', '주왕', '자연', '퇴촌부동산전시장I ', '삼동역현대', '재테크', '조은', '솔루션', '명인', '그린빌', '한승LG', '드림', '우림필유', '부창', '중앙', '화성랜드', '한울', '풍성', '송산면부동산', '온나라', '봉담한신더휴', '부오', '우미베스트', '행복부동산', '거성', '동탄114', '포스코탑', '우리', '국토', '성부부동산', '정다운', 'KB공장', '좋은터', '상정', '까치부동산', '스마트', '나라', '공장박사', '신태양', '부탁해홈즈', '도척행운부동산', '길성', '신도시', '동탄역예미지Swan', '대우푸르지오', '동성', '우미제일합동', '공장전문', '신현대', '유명', 'MK', '천일부동산', '부동산친구', '유진골드', '새현대 ', '씨월드', '미래', '풍성한', '임광일번지', '희망', '동탄역리치', '화성', '조은부동산', '박순자 ', '서울부동산', '경인', '다산', '현대', '예가', '서진', '제부도 부동산', '지오', '근형', '동탄월드', '하늘', 'OK', '3천리', '강남', '정명', '백지연부동산', '이너매스', '위너스타', '참누리', '쌍용', '신성', '한일', '일해부동산', '대우', '대우푸르지오', '대우푸르지오1', '신도', '행복한동문', '성호', '태양부동산', '영파크', '데일리캐슬', '향남재운', '풍성한', '경기', '늘푸른', '1등', '관리', '효자땅', '롯데캐슬', '한솔', '남양시티', '세원', '오복', '행복한', '승원', '소사홈부동산', '건국', '서해부동산', '대한', '베스트', '와우', '알짜', '정도', '가나안', '우신부동산', '칠보부동산', '신용부동산', '신창랜드', '금호어울림', '메타폴리스', '에이스', '화성부동산', '해찬', '영화 ', '신성미소지움', '동탄I PARK', '대우미래', '명문', '대광1차', '1단지', '153부동산', '제일', '신창우방', '세기', '두리', '동남훼미리', '병점역행운', '이문', '초월역행운', '원탑', '일신부동산', '삼성래미안 ', '정규', '부동산캠프', '토박이', '경기', '현대', '두산베스트', '뉴스', '나루월드', '우리', '한송이', '천산', '산업', '한국', '드림', '대원', '아너스빌', '시네마', '당하', '임광랜드', '가원', '래미안', '로또', '열린', '양감', '화성', '성우', '제부도', '터', '대흥', '한창', '홍광유', '푸르지오단지내', '전원', '대한', '한승어울림', '삼흥', '참누리베스트', '청솔', '한빛', '한신휴플러스', '남양', '우리들', '전원부동산', '황금', '한반도', '원주민부동산', '호반센트럴', '삼오', '이지', '현대힐스테이트', '월드부동산', '한샘', '샘물', '나경', '권의택', '경성', 'KCC미래', '이상식', '건국부동산컨설팅', '송산', '부강', '일진', '우남베스트', '신미주', '뉴종합부동산', '좋은집', '부동산프라자', '세종', '동남', '부동산119', '굿모닝', '서신', '동탄뱅크', '친구', '미르부동산', '한신', '우남블루존 ', '대원', '신현대', '양지', '발안', '옥토', '유진', '광주역우방부동산', '효성베스트', '아름집', '창화', '우리', '초월역모아', '초월프라임', '누리부동산', '경기광주', '동양부동산', '행복2', '태평양', '곤지암역우리', '힐스더드림', '금강', '우영', '신일', '누리', '서희스타', '카카오', '스타', '자이', '나나', '다온', '우남힐스테이트', '태전대림', '태양', '우림필유', '경남하나', '삼성플러스', '광주역', '광주태양', '밀의', '삼성', '스마트', '토탈', '에이스', '아트', '더샵금메달', '제일', '하우스투어', '국제J', '태성', '태전삼성', '신 나산', '광주114', '福', '원주민', '새에덴', '김경호', '나래', '천지', '최상권', '서경', '현대부동산', '윤영선', '허브', '미소', '삼성', '둥지', '종합', '팔당', '벽산', '광주역참', '광주역썬', '행운', '성신', '문형탑', '성실', '시티자이부동산', '더유일', '뉴동광', '경남', '로얄', '부동산정보닷컴', '숲', '대우', '초월역한라비발디', '강남', '황금', '초월역청담', '만복', '탄벌', '대통', '만나', '대박', '더원', '건업리', '나라', '새평화', '드림A', '예지', '태전이편한', '우방좋은집', '한국', '해드림', '남한산성', '미래', '꿈에그린', '포스코', '금터', '초월역e편한부동산', '윌', '현대', '영국중앙', '광장부동산', '금호', '국진', '사랑', '원부동산', '초월역롯데캐슬', '더샵오포', '광주역태영', '광주태전+', '이편한대림부동산', '희망', '옥산', '김앤김', '행복한집 ', '삼성', '광주역다올', '이음', '우방아이유쉘', '윤택한집', '하우스링크', '성원', '드림', '한울', '늘푸른', '강마을', '넘버원', '두탑', '소나무', '무궁화', '강남부동산', '삼동', '국민', '신용', '금성메니저', '태성', '資利(자리)', '나무', '이수', '우림필유', '한나부동산', '두꺼비', '현대아이파크', '황금', '에덴', '우정', '리안', '조양', '제일', '골드', '활기찬파크자이', '강남부동산', '예스현대', '강산', '영동', '태전힐스', '이레부동산', '태전밸리', '예스', '현진', '뉴신세계', '삼성', '김인수', '현대힐', 'I park & hill ', '명품플러스', '그랜드', '더베스트', '선경', '광주+이편한', '여명', '현대', 'ok', '금송부동산', '대길부동산', '대광', '대호', '최고', '삼성', '이레', '다원', '삼일', '우리부동산', '기안', '곤지암역전', '한국부동산', '고산지구', '가교', '공감', '경림', '성공부동산', '삼동역합동', '탑', '부자', '원', '진', '곤지암OK', '황금', '금강부동산', '평화자이', '유빈', '대주파크빌', 'ok', '초월역하나', '양지', '드림', '초원', '광주이편한', '제이앤유', '이음부동산', '엘리트', '현대자이', '호박', 'THE부동산', '태전OK부동산', '전철역', '롯데', '세종부동산', '솔로몬', '정기환', '광주역강남', '광주역', '일등', '태양', '영화', '토금', '제일', '태전행운', '송들', '강남', '라온', '매산부동산', '세양', '스타', '분원부동산', '구억', '동화마을', '열린', '신수지', '대박', '홈메이트', '두꺼비', '세무사법무사', '성원', '온누리', '중앙', '물빛', 'S한성', '권칠남법무사&', '모이세', '세계로', ' ...
