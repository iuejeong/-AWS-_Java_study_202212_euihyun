# %%
import numpy as np
import math

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

def split_len(data_list):
    len_list=[]
    for e in data_list:
        len_list.append(len(e))
    print(set(len_list))
    if len(set(len_list))>1:
        for i in set(len_list):
            print(i, len_list.count(i))
    return set(len_list)

def dist_np(p1, p2): #  [3,10]  [5,25]
    return math.sqrt(sum((p2-p1)**2))

# %%
csv_data = []
with open('전국공인중개사사무소표준데이터.csv') as f:
    for line in f:
        csv_data.append(my_split(line[:-1]))
        
np_data = np.array(csv_data)
for e in enumerate(np_data[0]):
    print(e)
# Out:
# (0, '중개사무소명')
# (1, '개설등록번호')
# (2, '개업공인중개사종별구분')
# (3, '소재지도로명주소')
# (4, '소재지지번주소')
# (5, '전화번호')
# (6, '개설등록일자')
# (7, '공제가입유무')
# (8, '대표자명')
# (9, '위도')
# (10, '경도')
# (11, '중개보조원수')
# (12, '소속공인중개사수')
# (13, '홈페이지주소')
# (14, '데이터기준일자')
# (15, '제공기관코드')
# (16, '제공기관명')

# %%
print(np_data[:3])
# Out:
# [['중개사무소명' '개설등록번호' '개업공인중개사종별구분' '소재지도로명주소' '소재지지번주소' '전화번호' '개설등록일자'
#   '공제가입유무' '대표자명' '위도' '경도' '중개보조원수' '소속공인중개사수' '홈페이지주소' '데이터기준일자'
#   '제공기관코드' '제공기관명']
#  ['제일공인중개사사무소' '26710-2015-00005' '공인중개사' '부산광역시 기장군 정관읍 구연로 26' '' ''
#   '2015-01-07' 'Y' '송미경' '' '' '' '' '' '2022-11-25' '3400000'
#   '부산광역시 기장군']
#  ['늘채움부동산공인중개사사무소' '26710-2015-00013' '공인중개사'
#   '"부산광역시 기장군 기장읍 차성남로 91, 1층 일부"' '' '' '2015-01-21' 'Y' '강경미' '' '' ''
#   '' '' '2022-11-25' '3400000' '부산광역시 기장군']]

# %%
btypes = np_data[1:, 2]
# print(btypes)
btype_name, btype_count = np.unique(btypes, return_counts = True)
print(btype_name)
print(btype_count)
print(btype_count * 100 / sum(btype_count))
# Out:
# ['개업공인중개사' '공인중개사' '법인']
# [ 5085 23757   527]
# [17.31417481 80.89141612  1.79440907]

# %%
y_n = np_data[1:, 7]
np.unique(y_n, return_counts=True)
# Out:
# (array(['N', 'Y'], dtype='<U74'), array([   30, 29339], dtype=int64))

# %%
names = np_data[1:, 0]
name_head = []
else_list = []
for n in names:
    n = n.replace(' ', '')
    if '공인중개사' in n:
        name_head.append(n[:n.index('공인중개사')])
    else:
        else_list.append(n)
print(else_list)
# Out:
# ['미스터홈즈부동산중개광주장지센터', '삼동역힐스테이트부동산중개', '천일부동산중개사무소', '만세부동산중개', '대일부동산중개사무소', '산들부동산중개사무소', '또또부동산중개사무소', '도시개발부동산중개', '금부동산중개사무소', '바른정부동산중개사무소', '대명부동산중개사무소', '신동부동산중개사무소', '신동부동산중개사무소', '신동부동산중개사무소', '명성부동산중개사무소', '현대부동산중개사무소', '황금알부동산중개사사무소', '여주역최고부동산중개사무소', '얼쑤부동산중개사무소', '아빠부동산중개사무소', '남양부동산중개사무소', '여수부동산중개사무소', '참진부동산중개사무소', '유창부동산중개사무소', '(유)해강부동산중개법인', '또바구부동산중개사무소', '해산부동산중개사무소', '성실부동산중개사무소', '웅